# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
raw_df = pd.read_csv(r"C:\Users\msi\Desktop\Senior_Semester2\ISS Senior Project\Code\AI-Financial-Assistant\aapl_2016_2020.csv")
raw_df
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_23888\3213442638.py:1: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_df = pd.read_csv(r"C:\Users\msi\Desktop\Senior_Semester2\ISS Senior Project\Code\AI-Financial-Assistant\aapl_2016_2020.csv")
#          [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]  \
# 0              1546462800   2019-01-02 16:00    2019-01-02
# 1              1546462800   2019-01-02 16:00    2019-01-02
# 2              1546462800   2019-01-02 16:00    2019-01-02
# 3              1546462800   2019-01-02 16:00    2019-01-02
# 4              1546462800   2019-01-02 16:00    2019-01-02
# ...                   ...                ...           ...
# 1015347        1490990400   2017-03-31 16:00    2017-03-31
# 1015348        1490990400   2017-03-31 16:00    2017-03-31
# 1015349        1490990400   2017-03-31 16:00    2017-03-31
# 1015350        1490990400   2017-03-31 16:00    2017-03-31
# 1015351        1490990400   2017-03-31 16:00    2017-03-31
#
#           [QUOTE_TIME_HOURS]   [UNDERLYING_LAST]  [EXPIRE_DATE]  \
# 0                       16.0              157.92     2019-01-04
# 1                       16.0              157.92     2019-01-04
# 2                       16.0              157.92     2019-01-04
# 3                       16.0              157.92     2019-01-04
# 4                       16.0              157.92     2019-01-04
# ...                      ...                 ...            ...
# 1015347                 16.0              143.67     2019-01-18
# 1015348                 16.0              143.67     2019-01-18
# 1015349                 16.0              143.67     2019-01-18
# 1015350                 16.0              143.67     2019-01-18
# 1015351                 16.0              143.67     2019-01-18
#
#           [EXPIRE_UNIX]   [DTE]  [C_DELTA]  [C_GAMMA]  ...  [P_LAST]  \
# 0            1546635600    2.00    0.90886    0.00019  ...      0.01
# 1            1546635600    2.00        1.0        0.0  ...      0.01
# 2            1546635600    2.00        1.0        0.0  ...      0.04
# 3            1546635600    2.00        1.0        0.0  ...      0.01
# 4            1546635600    2.00        1.0        0.0  ...      0.01
# ...                 ...     ...        ...        ...  ...       ...
# 1015347      1547845200  658.04    0.22786    0.00698  ...       0.0
# 1015348      1547845200  658.04    0.19785    0.00656  ...       0.0
# 1015349      1547845200  658.04    0.17574      0.006  ...     54.02
# 1015350      1547845200  658.04    0.15074    0.00556  ...     58.72
# 1015351      1547845200  658.04    0.11543    0.00462  ...       0.0
#
#          [P_DELTA]  [P_GAMMA]  [P_VEGA]  [P_THETA]  [P_RHO]      [P_IV]  \
# 0         -0.00034    0.00011   0.00079   -0.00509 -0.00041    1.625550
# 1         -0.00069     0.0001   0.00039   -0.00518  -0.0001    1.461900
# 2         -0.00066     0.0002       0.0   -0.00425 -0.00009    1.305490
# 3          -0.0012    0.00021   0.00089   -0.00434 -0.00005    1.155130
# 4         -0.00109    0.00024   0.00045   -0.00429  -0.0002    1.010620
# ...            ...        ...       ...        ...      ...         ...
# 1015347   -0.82994    0.00692   0.46146    -0.0087  -2.9731    0.177380
# 1015348    -0.8806    0.00575   0.35107   -0.00718  -3.1773    0.161320
# 1015349   -0.92501    0.00424   0.23292   -0.00537 -3.36887    0.145280
# 1015350   -0.96149    0.00233   0.11114    -0.0036 -3.54558    0.124590
# 1015351   -0.98523        0.0       0.0    -0.0028 -3.78515   -0.000170
#
#           [P_VOLUME]  [STRIKE_DISTANCE]   [STRIKE_DISTANCE_PCT]
# 0           0.000000               57.9                   0.367
# 1         200.000000               52.9                   0.335
# 2         706.000000               47.9                   0.303
# 3           0.000000               42.9                   0.272
# 4           0.000000               37.9                   0.240
# ...              ...                ...                     ...
# 1015347                            41.3                   0.288
# 1015348                            46.3                   0.322
# 1015349     0.000000               51.3                   0.357
# 1015350   183.000000               56.3                   0.392
# 1015351                            66.3                   0.462
#
# [1015352 rows x 33 columns]

# %% [markdown]
# Using `raw_df.info()`, we obtain a concise summary of our DataFrame, detailing entries, column names, non-null counts, and data types—essential for grasping our dataset's structure and prepping for data cleaning or manipulation.

# %%
raw_df.info() #inspecting the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015352 entries, 0 to 1015351
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   [QUOTE_UNIXTIME]        1015352 non-null  int64
#  1    [QUOTE_READTIME]       1015352 non-null  object
#  2    [QUOTE_DATE]           1015352 non-null  object
#  3    [QUOTE_TIME_HOURS]     1015352 non-null  float64
#  4    [UNDERLYING_LAST]      1015352 non-null  float64
#  5    [EXPIRE_DATE]          1015352 non-null  object
#  6    [EXPIRE_UNIX]          1015352 non-null  int64
#  7    [DTE]                  1015352 non-null  float64
#  8    [C_DELTA]              1015352 non-null  object
#  9    [C_GAMMA]              1015352 non-null  object
#  10   [C_VEGA]               1015352 non-null  object
#  11   [C_THETA]              1015352 non-null  object
#  12   [C_RHO]                1015352 non-null  object
#  13   [C_IV]                 1015352 non-null  object
#  14   [C_VOLUME]             1015352 non-null  object
#  15   [C_LAST]               1015352 non-null  object
#  16   [C_SIZE]               1015352 non-null  object
#  17   [C_BID]                1015352 non-null  object
#  18   [C_ASK]                1015352 non-null  object
#  19   [STRIKE]               1015352 non-null  float64
#  20   [P_BID]                1015352 non-null  object
#  21   [P_ASK]                1015352 non-null  object
#  22   [P_SIZE]               1015352 non-null  object
#  23   [P_LAST]               1015352 non-null  object
#  24   [P_DELTA]              1015352 non-null  object
#  25   [P_GAMMA]              1015352 non-null  object
#  26   [P_VEGA]               1015352 non-null  object
#  27   [P_THETA]              1015352 non-null  object
#  28   [P_RHO]                1015352 non-null  object
#  29   [P_IV]                 1015352 non-null  object
#  30   [P_VOLUME]             1015352 non-null  object
#  31   [STRIKE_DISTANCE]      1015352 non-null  float64
#  32   [STRIKE_DISTANCE_PCT]  1015352 non-null  float64
# dtypes: float64(6), int64(2), object(25)
# memory usage: 255.6+ MB

# %% [markdown]
# It always helps to have clean column names. In this notebook, I simply used list comprehension to remove unwanted characters from the raw column names. This makes accessing and reading columns by their names easier.

# %%
columns = raw_df.columns
columns = [s.replace('[', '') for s in columns]
columns = [s.replace(']', '') for s in columns]
columns = [s.replace(' ', '') for s in columns]

# %% [markdown]
# Some columns will not be handled well when converting raw numeric strings to Python's integer and float datatypes.
# Therefore, we will treat these features separately and join them again later.
#
# The code sequence enhances `raw_df` structure by distinguishing between date and numeric columns:
#
# - `raw_df.columns = columns`: Cleans column names for consistent future operations.
# - `date_columns = ['QUOTE_READTIME','QUOTE_DATE','EXPIRE_DATE']`: Identifies date columns, crucial for specific treatments like datetime conversion.
# - `numeric_cols = raw_df.columns.to_list()`: Assumes all columns could be numeric initially.
# - Removing date columns from `numeric_cols`: Isolates numeric data for operations like calculations or statistical analysis, ensuring `numeric_cols` accurately reflects numeric-only columns.
#
# This setup paves the way for precise data manipulation and analysis, like datetime formatting and numeric data operations.

# %%
raw_df.columns = columns
date_columns = ['QUOTE_READTIME','QUOTE_DATE','EXPIRE_DATE']
numeric_cols = raw_df.columns.to_list()
numeric_cols.remove('QUOTE_READTIME')
numeric_cols.remove('QUOTE_DATE')
numeric_cols.remove('EXPIRE_DATE')
numeric_cols
# Out:
# ['QUOTE_UNIXTIME',
#  'QUOTE_TIME_HOURS',
#  'UNDERLYING_LAST',
#  'EXPIRE_UNIX',
#  'DTE',
#  'C_DELTA',
#  'C_GAMMA',
#  'C_VEGA',
#  'C_THETA',
#  'C_RHO',
#  'C_IV',
#  'C_VOLUME',
#  'C_LAST',
#  'C_SIZE',
#  'C_BID',
#  'C_ASK',
#  'STRIKE',
#  'P_BID',
#  'P_ASK',
#  'P_SIZE',
#  'P_LAST',
#  'P_DELTA',
#  'P_GAMMA',
#  'P_VEGA',
#  'P_THETA',
#  'P_RHO',
#  'P_IV',
#  'P_VOLUME',
#  'STRIKE_DISTANCE',
#  'STRIKE_DISTANCE_PCT']

# %% [markdown]
# After categorizing the columns, the next steps focus on creating a purely numeric DataFrame and ensuring all its values are treated as numeric:
#
# - `numeric_df = raw_df.drop(columns=date_columns)`: This creates a new DataFrame, `numeric_df`, by removing the date columns from `raw_df`. The aim is to have a DataFrame that contains only numeric data, facilitating operations that apply exclusively to numeric types.
#
# - The loop iterates through `numeric_cols`, converting each column in `numeric_df` to a numeric type using `pd.to_numeric()`. The `errors='coerce'` parameter means that if conversion fails for any reason (e.g., a value that can't be turned into a number), it will be replaced with `NaN`, ensuring all values in `numeric_df` are either numeric or `NaN`.
#
# - `raw_df = numeric_df`: Finally, the original DataFrame `raw_df` is updated to be the newly created `numeric_df`. This step finalizes the conversion of the DataFrame to contain only numeric data, ready for further analysis or modeling.
#
# These actions streamline `raw_df` for numerical analysis by ensuring all data is appropriately formatted as numeric, removing potential obstacles for mathematical operations or statistical modeling.

# %%
numeric_df = raw_df.drop(columns=date_columns)

for i in numeric_cols:
    numeric_df[i] = pd.to_numeric(numeric_df[i], errors='coerce')
    
raw_df = numeric_df

# %%
raw_df.info() #CHECK THE UPDATED DATA FRAME, THE UPDATED DATAFRAME CONTAINS ONLY NUMERIC DATA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015352 entries, 0 to 1015351
# Data columns (total 30 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   QUOTE_UNIXTIME       1015352 non-null  int64
#  1   QUOTE_TIME_HOURS     1015352 non-null  float64
#  2   UNDERLYING_LAST      1015352 non-null  float64
#  3   EXPIRE_UNIX          1015352 non-null  int64
#  4   DTE                  1015352 non-null  float64
#  5   C_DELTA              1015336 non-null  float64
#  6   C_GAMMA              1015336 non-null  float64
#  7   C_VEGA               1015336 non-null  float64
#  8   C_THETA              1015336 non-null  float64
#  9   C_RHO                1015336 non-null  float64
#  10  C_IV                 946065 non-null   float64
#  11  C_VOLUME             690632 non-null   float64
#  12  C_LAST               1014138 non-null  float64
#  13  C_SIZE               0 non-null        float64
#  14  C_BID                1014137 non-null  float64
#  15  C_ASK                1014137 non-null  float64
#  16  STRIKE               1015352 non-null  float64
#  17  P_BID                1014130 non-null  float64
#  18  P_ASK                1014129 non-null  float64
#  19  P_SIZE               0 non-null        float64
#  20  P_LAST               1014131 non-null  float64
#  21  P_DELTA              1015336 non-null  float64
#  22  P_GAMMA              1015336 non-null  float64
#  23  P_VEGA               1015336 non-null  float64
#  24  P_THETA              1015336 non-null  float64
#  25  P_RHO                1015336 non-null  float64
#  26  P_IV                 953643 non-null   float64
#  27  P_VOLUME             658447 non-null   float64
#  28  STRIKE_DISTANCE      1015352 non-null  float64
#  29  STRIKE_DISTANCE_PCT  1015352 non-null  float64
# dtypes: float64(28), int64(2)
# memory usage: 232.4 MB

# %% [markdown]
# **We will now, write the required functions to predict our option prices**

# %%
from abc import ABC, abstractmethod
from dataclasses import dataclass
import numpy as np
import pandas as pd

# %% [markdown]
# **Defining an abstract class for Stochastic Process**
# class StochasticProcess(ABC): Defines an abstract base class named StochasticProcess that inherits from ABC. This class will serve as a template for stochastic processes.
# """Represente a Stochastic process""": A docstring explaining that this class represents a stochastic process.
# @abstractmethod: A decorator indicating that the following method is abstract and must be implemented by any subclass inheriting from StochasticProcess.
# def simulate(self): ...: Defines an abstract method simulate. The ... (ellipsis) indicates a placeholder with no implementation, enforcing subclasses to provide their own implementation of this method.

# %%
class StochasticProcess(ABC):
    """Represents a Stochastic process"""

    @abstractmethod
    def simulate(self):
        ...

# %% [markdown]
# **Geometirc Brownian Motion**
#
# Defines the simulate method with parameters for the initial stock price (s0), time horizon (T), number of paths (n), number of discretization points (m), and initial volatility (v0, which is not used in GBM but included for compatibility). The method returns a DataFrame, although the correct return type should be a NumPy array based on the implementation.

# %%
@dataclass
class GeometricBrownianMotion(StochasticProcess):

   """
    A classic geometric brownian motion which can be simulated.
    The closed form formula allow a fully vectorized calculation of the paths.
    """
mu: float #mu: The risk-free rate or the expected return of the asset.
sigma: float #kappa: The speed of reversion for the volatility to its long-term mean.

def simulate(self,s0:float,T:int,n:int,m:int,v0:float = None) -> pd.DataFrame: #n is number of paths, m is the number of discretization points.

        dt = T / m
        np.random.seed(0)
        W = np.cumsum(np.sqrt(dt) * np.random.randn(m + 1, n), axis=0)
        W[0] = 0

        T = np.ones(n).reshape(1, -1) * np.linspace(0, T, m + 1).reshape(-1, 1)

        s = s0 * np.exp((self.mu - 0.5 * self.sigma**2) * T + self.sigma * W)

        return s

# %% [markdown]
# - `s0`: Initial stock price.
# - `T`: Total time horizon for the simulation.
# - `n`: Number of paths to simulate (number of simulations).
# - `m`: Number of discretization points (time steps).
# - `v0`: Initial volatility, which is not used in the GBM model (included for compatibility with other models).
# - `s`: s represents the simulated asset prices over time, following a geometric Brownian motion (GBM) model. The GBM model is a stochastic process that is widely used in finance for modeling the dynamics of various financial instruments, such as stock prices.

# %% [markdown]
# **Definition of Heston Process Class**

# %% [markdown]
# This code defines a class HestonProcess that inherits from StochasticProcess and is intended for simulating the price movements of an asset (in this case, options on Apple stock) using the Heston model. The Heston model is a stochastic volatility model used in financial mathematics to describe the evolution of an asset's price and its volatility.
#
# - `mu`: The drift term or the risk-free rate, representing the expected return of the asset.
# - `kappa`: The speed of reversion of the volatility to its mean.
# - `theta`: The long-term mean volatility.
# - `eta`: The volatility of the volatility, indicating how much the volatility itself can vary.
# - `rho`: The correlation between the asset's returns and its volatility. This is crucial for modeling the leverage effect, where asset prices and their volatility are inversely correlated.

# %%
from dataclasses import dataclass
import numpy as np
import pandas as pd
# Plus the import statement for your StochasticProcess class

# %%
@dataclass
class HestonProcess(StochasticProcess):
    """
    An Heston process which can be simulated using Milstein schema.
    """

    mu: float
    kappa: float
    theta: float
    eta: float
    rho: float

    def simulate(
        self, s0: float, v0: float, T: int, n: int, m: int
    ) -> pd.DataFrame:  # n = number of paths, m = number of discretization points

        dt = T / m
        z1 = np.random.randn(m, n)
        z2 = self.rho * z1 + np.sqrt(1 - self.rho**2) * np.random.randn(m, n)

        s = np.zeros((m + 1, n))
        x = np.zeros((m + 1, n))
        v = np.zeros((m + 1, n))

        s[0] = s0
        v[0] = v0

        for i in range(m):

            v[i + 1] = (
                v[i]
                + self.kappa * (self.theta - v[i]) * dt
                + self.eta * np.sqrt(v[i] * dt) * z1[i]
                + self.eta**2 / 4 * (z1[i] ** 2 - 1) * dt
            )
            v = np.where(v > 0, v, -v)

            x[i + 1] = x[i] + (self.mu - v[i] / 2) * dt + np.sqrt(v[i] * dt) * z2[i]

            s[1:] = s[0] * np.exp(x[1:])

        return s

# %% [markdown]
# **Simulate Method**
# - This method definition starts with def, indicating a function or method. simulate is the name of the method. This method simulates the price paths of an asset using the Heston model parameters.
# self: Refers to the instance of the HestonProcess class, allowing access to its attributes and methods.
# - `s0`: Initial asset price.
# - `v0`: Initial volatility level.
# - `T`: The total simulation time.
# - `n`: Number of paths to simulate.
# - `m`: Number of time steps in each path.
# - `-> pd.DataFrame`: Specifies that this method returns a pandas DataFrame.

# %% [markdown]
# **Option Class Definition**

# %%
@dataclass
class Option():
    s0: float
    v0: float
    T: float
    K:float
    call: bool

    def payoff(self, s: np.ndarray) -> np.ndarray:
        payoff = np.maximum(s - self.K, 0) if self.call else np.maximum(self.K - s, 0)
        return payoff

# %% [markdown]
# **Explanation:**
#
# *Attributes*:
# - `s0`: The initial price of the underlying asset.
# - `T`: The expiration time of the option.
# - `K`: The strike price of the option, i.e., the price at which the holder can buy (call option) or sell (put option) the underlying asset.
# - `v0`: The initial volatility of the underlying asset's price (optional, defaults to `None`). This could be used in models that require volatility as an input.
# - `call`: A boolean indicating whether the option is a call option (`True`) or a put option (`False`). Defaults to `True`, meaning it's a call option unless specified otherwise.
#
# *Payoff Method*
# - `definition`: This line defines a method named payoff for the Option class. The method calculates the payoff of the option given the final price(s) of the underlying asset. The method accepts an np.ndarray representing the final price(s) s of the underlying asset and returns an np.ndarray of the payoff values.
#
# - `Usage`: This line calculates the payoff of the option. For a call option (self.call == True), the payoff is the maximum of s - self.K and 0, representing the profit from exercising the option when the final price s is above the strike price K, and zero otherwise. For a put option (self.call == False), it calculates the maximum of self.K - s and 0, representing the profit from exercising the option when the final price s is below the strike price K, and zero otherwise.

# %% [markdown]
# **Defining Monte Carlo Simulation Function**

# %%
import numpy as np
from numpy.polynomial import Polynomial
from scipy.stats import norm


def monte_carlo_simulation(option: Option, process: StochasticProcess, n: int, m: int, alpha: float = 0.05) -> float:
    """
    Given an option and a process followed by the underlying, calculate the classic monte carlo price estimator
    """
    # n = number of paths, m = number of discretization points
    s = process.simulate(s0=option.s0, v0=option.v0, T=option.T, n=n, m=m)
    st = s[-1]
    payoffs = option.payoff(s=st)

    discount = np.exp(-process.mu * option.T)
    price = np.mean(payoffs) * discount

    quantile = norm.ppf(1 - alpha / 2)
    confidence_interval = [
        np.round(price - quantile * np.std(payoffs * discount) / np.sqrt(n), 2),
        np.round(price + quantile * np.std(payoffs * discount) / np.sqrt(n), 2),
    ]

    print(f"The price of {option!r} = {price:.2f}")
    print(f"{(1-alpha)*100}% confidence interval = {confidence_interval}")

    return np.round(price, 2)

# %% [markdown]
# **Explanation of the Monte Carlo Simulation Function**
# ## Monte Carlo Simulation for Option Pricing
#
# This function estimates the price of an option using the Monte Carlo simulation method. It takes into account the dynamics of the underlying asset modeled by a given stochastic process (e.g., the Heston process).
#
# ### Parameters
# - `option`: An `Option` object containing initial parameters like the initial stock price (`s0`), initial volatility (`v0`), and time to maturity (`T`).
# - `process`: A `StochasticProcess` object responsible for simulating the path of the underlying asset.
# - `n`: The number of paths to simulate.
# - `m`: The number of discretization points per path.
# - `alpha`: The significance level for the confidence interval (default is 5%).
#
# ### Procedure
# 1. Simulate `n` paths for the underlying asset using the specified `process`.
# 2. Calculate the option payoffs based on the final simulated asset prices.
# 3. Discount the mean payoff to present value to estimate the option price.
# 4. Calculate a confidence interval for the price estimate to quantify the estimation uncertainty.
#
# The function provides a practical approach to option pricing, incorporating the randomness of the underlying asset's movements through simulation. It returns the estimated price of the option along with a confidence interval, offering insight into the precision of the estimate.

# %% [markdown]
# **Defining Monte Carlo Simulation x Longstaff-SchwartzFunction**
# ## Explanation
# ## Monte Carlo Simulation with Longstaff-Schwartz Algorithm
#
# The `monte_carlo_simulation_LS` function implements the Longstaff-Schwartz algorithm for option pricing through Monte Carlo simulation. This method is particularly suited for pricing American options, where the option holder has the right to early exercise. Here's an overview of the function implementation:
#
# ### Function Inputs
#
# - `Option` object: Contains option specifics such as initial price (`s0`), volatility (`v0`), and time to maturity (`T`).
# - `StochasticProcess` object: Defines the dynamics of the underlying asset price.
# - `n`: Number of Monte Carlo simulation paths.
# - `m`: Number of time discretization points.
# - `alpha`: Confidence level for the price estimation (default is 0.05, not used in this code block).
#
# ### Key Steps in the Algorithm
#
# 1. **Path Simulation**: Simulate `n` paths of the underlying asset's price over `m` time steps.
# 2. **Payoff Calculation**: For each simulated path, calculate the option's payoff at every time step.
# 3. **Option Value Initialization**: Initialize an array to store the option values, setting the final values to the corresponding payoffs.
# 4. **Discount Factor**: Compute the discount factor using the risk-free rate and the time step size.
# 5. **Backward Induction**: Starting from the end of the option's life, move backward in time, at each step deciding whether to exercise the option or continue holding it based on a polynomial fit of continuation values.
# 6. **Price Estimation**: Estimate the option price as the discounted mean of the option values at the first time step.
#
# ### Output
#
# The function prints and returns the estimated price of the option, rounded to four decimal places.

# %%
def monte_carlo_simulation_LS(option: Option, process: StochasticProcess, n: int, m: int, alpha: float = 0.05) -> float:
    """
    Given an option and a process followed by the underlying, calculate the option value using the Longstaff-Schwartz algorithme
    """
    # n = number of path, m = number of discretization points

    s = process.simulate(s0=option.s0, v0=option.v0, T=option.T, n=n, m=m)

    payoffs = option.payoff(s=s)

    v = np.zeros_like(payoffs)
    v[-1] = payoffs[-1]

    dt = option.T / m
    discount = np.exp(-process.mu * dt)

    for t in range(m - 1, 0, -1):
        polynome = Polynomial.fit(s[t], discount * v[t + 1], 5)
        c = polynome(s[t])
        v[t] = np.where(payoffs[t] > c, payoffs[t], discount * v[t + 1])

    price = discount * np.mean(v[1])

    print(f"The price of {option!r} = {round(price, 4)}")

    return round(price, 4)

# %% [markdown]
# ## Defining the Black-Scholes-Merton Function

# %%
def black_scholes_merton(r, sigma, option: Option):
    """
    Calculate the price of vanilla options using BSM formula
    """
    d1 = (np.log(option.s0 / option.K) + (r + sigma**2 / 2) * option.T) / (sigma * np.sqrt(option.T))
    d2 = d1 - sigma * np.sqrt(option.T)

    price = option.s0 * norm.cdf(d1) - option.K * np.exp(-r * option.T) * norm.cdf(d2)
    price = price if option.call else price - option.s0 + option.K * np.exp(-r * option.T)

    return np.round(price, 2)

# %% [markdown]
# ## Explanation
# ### Black-Scholes-Merton Option Pricing Function
#
# This function utilizes the Black-Scholes-Merton (BSM) formula to calculate the price of vanilla options, both calls and puts. It's structured to handle the fundamental variables of option pricing within a financial context.
#
# #### Parameters:
# - `r`: Risk-free interest rate, indicating the return of an investment with no risk over a specific period.
# - `sigma`: Volatility of the underlying asset's returns, a measure of how much the asset's price is expected to fluctuate.
# - `option`: An instance of the `Option` class with attributes:
#   - `s0`: Current price of the underlying asset.
#   - `K`: Strike price of the option.
#   - `T`: Time to expiration of the option, in the same units as `r`.
#   - `call`: Boolean indicating if the option is a call (`True`) or put (`False`).
#
# #### Formula Components:
# - **`d1` and `d2`**: Intermediate calculations that incorporate the current asset price, strike price, time to expiration, risk-free rate, and volatility to derive option pricing.
# - **Option Price Calculation**:
#   - For a call option: `price = s0 * norm.cdf(d1) - K * exp(-r * T) * norm.cdf(d2)`
#   - For a put option: Adjusts the call price to account for the option type: `price = price - s0 + K * exp(-r * T)`
#
# The result is the option price, rounded to two decimal places.

# %% [markdown]
# ## Defining the Cox-Ross-Rubinstein (CRR) model

# %%
def crr_pricing(r=0.1, sigma=0.2, option: Option = Option(s0=100, T=1, K=100, v0=None, call=False), n=25000):
    """
    Calculate the price of an americain option using a backward tree model
    """
    dt = option.T / n
    u = np.exp(sigma * np.sqrt(dt))
    d = 1 / u
    a = np.exp(r * dt)
    p = (a - d) / (u - d)
    q = 1 - p

    st = np.array([option.s0 * u**i * d ** (n - i) for i in range(n + 1)])
    v = np.maximum(option.K - st, 0)

    for _ in range(n):
        v[:-1] = np.exp(-r * dt) * (p * v[1:] + q * v[:-1])
        st = st * u
        v = np.maximum(v, option.K - st)

    return np.round(v[0], 3)

# %% [markdown]
# ## Explanation
# ## American Option Pricing Using Cox-Ross-Rubinstein (CRR) Model
#
# This section outlines the implementation of the CRR model to price American options through a binomial tree approach. The function `crr_pricing` encapsulates the logic for this calculation based on several parameters and the option's characteristics.
#
# ### Parameters
#
# - `r`: The risk-free interest rate, annualized.
# - `sigma`: The volatility of the underlying asset, annualized.
# - `option`: An instance of the `Option` class, containing:
#   - `s0`: Initial stock price.
#   - `T`: Time to expiration in years.
#   - `K`: Strike price.
#   - `call`: Boolean indicating if the option is a call (False implies it's a put).
# - `n`: Number of steps in the binomial tree, affecting the model's accuracy and computational complexity.
#
# ### Process Overview
#
# 1. **Initialization:**
#    - Calculate the length of each time interval (`dt`) in the binomial tree.
#    - Determine the up (`u`) and down (`d`) factors for stock price movement, and the risk-free growth factor (`a`).
#    - Compute risk-neutral probabilities (`p` for up, `q` for down movements).
#
# 2. **Stock Price and Option Value at Maturity:**
#    - Generate the possible stock prices at maturity within the binomial tree.
#    - Initialize the option values at maturity based on their intrinsic value (difference between strike price and stock prices for a put option).
#
# 3. **Backward Induction:**
#    - Iterate backward through the tree to calculate the option value at each step, considering the maximum value between holding and exercising the option early (for American options).
#
# ### Return Value
#
# The function returns the calculated option price at the current time, rounded to three decimal places. This approach effectively models the early exercise feature inherent to American options, providing a flexible method to estimate their pricing.

# %%
raw_df
# Out:
#          QUOTE_UNIXTIME  QUOTE_TIME_HOURS  UNDERLYING_LAST  EXPIRE_UNIX  \
# 0            1546462800              16.0           157.92   1546635600
# 1            1546462800              16.0           157.92   1546635600
# 2            1546462800              16.0           157.92   1546635600
# 3            1546462800              16.0           157.92   1546635600
# 4            1546462800              16.0           157.92   1546635600
# ...                 ...               ...              ...          ...
# 1015347      1490990400              16.0           143.67   1547845200
# 1015348      1490990400              16.0           143.67   1547845200
# 1015349      1490990400              16.0           143.67   1547845200
# 1015350      1490990400              16.0           143.67   1547845200
# 1015351      1490990400              16.0           143.67   1547845200
#
#             DTE  C_DELTA  C_GAMMA   C_VEGA  C_THETA    C_RHO  ...  P_LAST  \
# 0          2.00  0.90886  0.00019  0.01709 -0.10040  0.00074  ...    0.01
# 1          2.00  1.00000  0.00000  0.00000  0.00000  0.00000  ...    0.01
# 2          2.00  1.00000  0.00000  0.00000  0.00000  0.00000  ...    0.04
# 3          2.00  1.00000  0.00000  0.00000  0.00000  0.00000  ...    0.01
# 4          2.00  1.00000  0.00000  0.00000  0.00000  0.00000  ...    0.01
# ...         ...      ...      ...      ...      ...      ...  ...     ...
# 1015347  658.04  0.22786  0.00698  0.58038 -0.00919  0.49007  ...    0.00
# 1015348  658.04  0.19785  0.00656  0.53588 -0.00861  0.43134  ...    0.00
# 1015349  658.04  0.17574  0.00600  0.49672 -0.00794  0.38433  ...   54.02
# 1015350  658.04  0.15074  0.00556  0.45069 -0.00665  0.33430  ...   58.72
# 1015351  658.04  0.11543  0.00462  0.37549 -0.00572  0.25918  ...    0.00
#
#          P_DELTA  P_GAMMA   P_VEGA  P_THETA    P_RHO     P_IV  P_VOLUME  \
# 0       -0.00034  0.00011  0.00079 -0.00509 -0.00041  1.62555       0.0
# 1       -0.00069  0.00010  0.00039 -0.00518 -0.00010  1.46190     200.0
# 2       -0.00066  0.00020  0.00000 -0.00425 -0.00009  1.30549     706.0
# 3       -0.00120  0.00021  0.00089 -0.00434 -0.00005  1.15513       0.0
# 4       -0.00109  0.00024  0.00045 -0.00429 -0.00020  1.01062       0.0
# ...          ...      ...      ...      ...      ...      ...       ...
# 1015347 -0.82994  0.00692  0.46146 -0.00870 -2.97310  0.17738       NaN
# 1015348 -0.88060  0.00575  0.35107 -0.00718 -3.17730  0.16132       NaN
# 1015349 -0.92501  0.00424  0.23292 -0.00537 -3.36887  0.14528       0.0
# 1015350 -0.96149  0.00233  0.11114 -0.00360 -3.54558  0.12459     183.0
# 1015351 -0.98523  0.00000  0.00000 -0.00280 -3.78515 -0.00017       NaN
#
#          STRIKE_DISTANCE  STRIKE_DISTANCE_PCT
# 0                   57.9                0.367
# 1                   52.9                0.335
# 2                   47.9                0.303
# 3                   42.9                0.272
# 4                   37.9                0.240
# ...                  ...                  ...
# 1015347             41.3                0.288
# 1015348             46.3                0.322
# 1015349             51.3                0.357
# 1015350             56.3                0.392
# 1015351             66.3                0.462
#
# [1015352 rows x 30 columns]

# %% [markdown]
# ## Applying Heston Model to Option Pricing
# ## Heston Model Parameters Explained
#
# The Heston model is a sophisticated tool for option pricing that takes into account the stochastic nature of volatility. Here are the key parameters it uses:
#
# - **S (Spot Price):** The current market price of the underlying asset, such as a stock. This value serves as the starting point for the model's simulations.
#
# - **K (Strike Price):** The agreed-upon price at which the option holder can either buy (in the case of a call option) or sell (in the case of a put option) the underlying asset. This price is fixed and determined when the option is purchased.
#
# - **T (Time to Maturity):** The duration remaining until the option expires, typically expressed in years. The value of an option tends to decline as it approaches its expiration date, influenced by factors such as volatility and movements in the underlying asset's price.
#
# - **mu (Risk-free Interest Rate):** Represented by "μ", this is the theoretical return on an investment that is considered free of risk, usually based on the yield of government bonds. It's used to discount the future payoff of the option to its present value.
#
# - **V0 (Initial Volatility):** Represents the current level of volatility in the returns of the underlying asset. In the Heston model, this initial volatility is a starting point that evolves over time following a stochastic process.
#
# - **kappa (Mean Reversion Speed):** Determines the rate at which volatility reverts to its long-term mean value (theta). A higher value of kappa indicates a quicker reversion, suggesting that volatility shocks are short-lived.
#
# - **theta (Long-term Variance):** The average long-term variance of the underlying asset's price. The model assumes that volatility will revert to this level over time, following the mean-reverting process.
#
# - **eta (Volatility of Variance):** Also referred to as the "vol of vol", this parameter quantifies the volatility of the asset's volatility itself. A higher eta value implies that the underlying asset's volatility can undergo more significant changes, which in turn affects option pricing.
#
# - **rho (Correlation):** Measures the correlation between the returns of the underlying asset and its volatility. A negative correlation is typical in equity markets and indicates that volatility tends to increase as stock prices decrease. This relationship is key in capturing asymmetric volatility patterns in the Heston model.

# %%
dataset = pd.DataFrame()

dataset["S"] = raw_df["UNDERLYING_LAST"]
dataset["K"] = raw_df["STRIKE"]
dataset["PRICE"] = raw_df["C_BID"]
dataset["mu"] = raw_df["C_RHO"]/(raw_df["C_BID"]*100)
dataset["T"] = raw_df["DTE"]/365



dataset.head()
# Out:
#         S      K  PRICE            mu         T
# 0  157.92  100.0  57.70  1.282496e-07  0.005479
# 1  157.92  105.0  52.50  0.000000e+00  0.005479
# 2  157.92  110.0  47.45  0.000000e+00  0.005479
# 3  157.92  115.0  40.70  0.000000e+00  0.005479
# 4  157.92  120.0  35.71  0.000000e+00  0.005479

# %% [markdown]
# ## What was done?

# %% [markdown]
# ## Data Preparation for Option Pricing Analysis
#
# The following steps were taken to prepare the dataset for option pricing analysis from a raw DataFrame (`raw_df`):
#
# 1. **Initialization of a New DataFrame:**
#    - A new DataFrame `dataset` is created to structure the data needed for option pricing.
#
# 2. **Spot Price (S):**
#    - The `UNDERLYING_LAST` column from `raw_df` is used to populate the `S` column in `dataset`, representing the current market price of the underlying asset for each option.
#
# 3. **Strike Price (K):**
#    - The `STRIKE` column from `raw_df` fills the `K` column in `dataset`, indicating the price at which the option can be exercised.
#
# 4. **Option Bid Price:**
#    - The bid price of the options, sourced from the `C_BID` column in `raw_df`, is assigned to the `PRICE` column in `dataset`. This reflects the current buying price of the call options.
#
# 5. **Risk-free Interest Rate (mu):**
#    - The risk-free interest rate (`mu`) is calculated for each option using the formula `raw_df["C_RHO"] / (raw_df["C_BID"] * 100)` and stored in the `mu` column. This calculation leverages the rho value of each option, which measures its sensitivity to changes in interest rates.
#
# 6. **Time to Maturity (T):**
#    - The time until each option expires is calculated by dividing the `DTE` (Days to Expiry) from `raw_df` by 365, converting it into years. This value is stored in the `T` column of `dataset`.
#
# 7. **Previewing the Dataset:**
#    - The `head()` function is called on `dataset` to display the first few rows, providing a quick overview of the data structure and the preprocessing steps applied.
#
# This preparation phase is crucial for aligning the raw option data (`raw_df`) with the requirements for further analysis or application in option pricing models.

# %%
dataset = dataset.reset_index(drop=True)

bigdata = dataset
smalldata = dataset[0:5]


smalldata
# Out:
#         S      K  PRICE            mu         T
# 0  157.92  100.0  57.70  1.282496e-07  0.005479
# 1  157.92  105.0  52.50  0.000000e+00  0.005479
# 2  157.92  110.0  47.45  0.000000e+00  0.005479
# 3  157.92  115.0  40.70  0.000000e+00  0.005479
# 4  157.92  120.0  35.71  0.000000e+00  0.005479
# 5  157.92  121.0  34.69  0.000000e+00  0.005479
# 6  157.92  122.0  33.65  0.000000e+00  0.005479
# 7  157.92  123.0  32.71  0.000000e+00  0.005479
# 8  157.92  124.0  31.80  0.000000e+00  0.005479
# 9  157.92  125.0  30.70  0.000000e+00  0.005479

# %% [markdown]
# ## Data Subset Creation
#
# After preparing the dataset for analysis, the following operations were performed to manage and explore subsets of the data:
#
# 1. **Resetting the Index:**
#    - The `reset_index(drop=True)` method is applied to `dataset`, which resets the DataFrame's index to the default integer index. The `drop=True` parameter discards the old index instead of adding it as a new column. This is often done to clean up the index after operations like sorting or filtering that may have altered the original order or introduced gaps.
#
# 2. **Creating a Full Data Copy:**
#    - `bigdata` is assigned the entire `dataset`. This operation does not actually create a new copy of the data in memory. Instead, `bigdata` and `dataset` now refer to the same DataFrame object. Any changes made to `bigdata` will reflect in `dataset` and vice versa, unless a method like `.copy()` is explicitly used to create a deep copy.
#
# 3. **Creating a Subset of Data:**
#    - `smalldata` is created as a subset of `dataset`, containing only the first two rows (index 0 and 1) based on the syntax `dataset[0:2]`. This slicing operation is useful for testing, analysis, or operations on a smaller portion of the data for efficiency or demonstration purposes.
#
# These steps are part of data management workflows in pandas, enabling precise control over data selection, manipulation, and exploration.

# %%
from math import * 
from scipy.stats import norm
from scipy.optimize import fmin_bfgs
from scipy import *
from scipy.integrate import quad
from scipy import optimize

# %%
# Calibration(kappa, theta, sigma, rho, v0)
def calibrate(init_val, market_datas):
    def error(x):
        kappa, theta, eta, rho, v0 = x
        print('x=',kappa, theta, eta, rho, v0)
        result = 0.0
        for i in range(0,len(market_datas)):
            s0, k, market_price, r, T = market_datas.iloc[i]
            #print(s0, k, market_price, r, T)
            
            heston = HestonProcess(mu=r, kappa=kappa, theta=theta, eta=eta, rho=rho)
            opt = Option(s0=s0, v0=v0, T=T, K=k, call=True)
            
            heston_price = monte_carlo_simulation_LS(option=opt, process=heston, n=5, m=252)
            result += (heston_price - market_price)**2
            
        print('** resulting error: ',result)
        return result
    opt=optimize.least_squares(error,init_val) # ??? or fmin, or leastsq
    return opt

# %%
market_datas = smalldata
market_datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S       10 non-null     float64
#  1   K       10 non-null     float64
#  2   PRICE   10 non-null     float64
#  3   mu      10 non-null     float64
#  4   T       10 non-null     float64
# dtypes: float64(5)
# memory usage: 532.0 bytes

# %% [markdown]
# # Optimizing

# %%
# Initialize kappa, theta, sigma, rho, v0
init_val = [1.1,0.1,0.4,-0.0,0.1]

# Calibration of parameters
# %time res = calibrate(init_val, market_datas) #very slow!!!!!
#kappa, theta, sigma, rho, v0=res
# Out:
# x= 1.1 0.1 0.4 -0.0 0.1
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=100.0, call=True) = 60.896
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=105.0, call=True) = 55.3618
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=110.0, call=True) = 51.961
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=115.0, call=True) = 44.869
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=120.0, call=True) = 43.0052
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=121.0, call=True) = 41.0953
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\polynomial\polynomial.py:1362: RankWarning: The fit may be poorly conditioned
#   return pu._fit(polyvander, x, y, deg, rcond, full, w)
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=122.0, call=True) = 38.9783
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=123.0, call=True) = 37.5777
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=124.0, call=True) = 37.6654
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=125.0, call=True) = 36.0368
# ** resulting error:  265.35144395
# x= 1.1000000163912773 0.1 0.4 0.0 0.1
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=100.0, call=True) = 61.9499
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=105.0, call=True) = 53.6863
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=110.0, call=True) = 50.6484
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=115.0, call=True) = 43.6526
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=120.0, call=True) = 43.2361
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=121.0, call=True) = 40.442
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=122.0, call=True) = 39.96
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=123.0, call=True) = 36.8105
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=124.0, call=True) = 36.401
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=125.0, call=True) = 38.3697
# ** resulting error:  264.76795157000004
# x= 1.1 0.1000000149011612 0.4 0.0 0.1
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=100.0, call=True) = 62.566
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=105.0, call=True) = 56.1802
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=110.0, call=True) = 51.2624
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=115.0, call=True) = 46.2881
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=120.0, call=True) = 41.2561
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=121.0, call=True) = 38.2569
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=122.0, call=True) = 39.0587
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=123.0, call=True) = 38.9416
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=124.0, call=True) = 38.0206
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=125.0, call=True) = 35.1898
# ** resulting error:  253.40612688000002
# x= 1.1 0.1 0.4000000149011612 0.0 0.1
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=100.0, call=True) = 60.4314
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=105.0, call=True) = 54.4867
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=110.0, call=True) = 54.5094
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=115.0, call=True) = 46.1899
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=120.0, call=True) = 40.2521
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=121.0, call=True) = 38.1663
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=122.0, call=True) = 38.1564
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=123.0, call=True) = 39.099
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=124.0, call=True) = 35.5171
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=125.0, call=True) = 34.113
# ** resulting error:  210.68935068999983
# x= 1.1 0.1 0.4 1.4901161193847656e-08 0.1
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=100.0, call=True) = 61.0762
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=105.0, call=True) = 55.0352
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=110.0, call=True) = 50.0083
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=115.0, call=True) = 44.3842
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=120.0, call=True) = 39.3372
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=121.0, call=True) = 42.2205
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=122.0, call=True) = 40.1034
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=123.0, call=True) = 36.4202
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=124.0, call=True) = 35.4136
# The price of Option(s0=157.92, v0=0.1, T=0.005479452054794521, K=125.0, call=True) = 35.4314
# ** resulting error:  198.66541062000002
# x= 1.1 0.1 0.4 0.0 0.1000000149011612
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=100.0, call=True) = 60.7959
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=105.0, call=True) = 58.209
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=110.0, call=True) = 51.8318
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=115.0, call=True) = 46.2762
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=120.0, call=True) = 40.5739
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=121.0, call=True) = 40.0517
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=122.0, call=True) = 37.3424
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=123.0, call=True) = 38.2075
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=124.0, call=True) = 36.362
# The price of Option(s0=157.92, v0=0.1000000149011612, T=0.005479452054794521, K=125.0, call=True) = 36.2694
# ** resulting error:  240.56318996000002
# x= 1.1069094631574805 0.2555963773299067 1.1120132214728697 0.8686337201302472 0.42288490113537125
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=100.0, call=True) = 61.4756
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=105.0, call=True) = 56.8916
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=110.0, call=True) = 55.4375
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=115.0, call=True) = 48.4635
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=120.0, call=True) = 45.515
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=121.0, call=True) = 44.6354
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=122.0, call=True) = 41.0979
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=123.0, call=True) = 41.1615
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=124.0, call=True) = 39.7724
# The price of Option(s0=157.92, v0=0.42288490113537125, T=0.005479452054794521, K=125.0, call=True) = 40.6192
# ** resulting error:  641.5111576399999
# x= 1.1017273657893702 0.13889909433247669 0.5780033053682174 0.2171584300325618 0.18072122528384282
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=100.0, call=True) = 62.2028
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=105.0, call=True) = 57.173
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=110.0, call=True) = 51.7871
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=115.0, call=True) = 51.703
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=120.0, call=True) = 39.1196
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=121.0, call=True) = 41.1779
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=122.0, call=True) = 38.2809
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=123.0, call=True) = 38.224
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=124.0, call=True) = 38.1682
# The price of Option(s0=157.92, v0=0.18072122528384282, T=0.005479452054794521, K=125.0, call=True) = 37.8733
# ** resulting error:  379.56643576000005
# x= 1.1004318414473426 0.10972477358311918 0.4445008263420544 0.05428960750814046 0.1201803063209607
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=100.0, call=True) = 61.4058
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=105.0, call=True) = 56.2684
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=110.0, call=True) = 51.1806
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=115.0, call=True) = 45.8229
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=120.0, call=True) = 41.3264
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=121.0, call=True) = 39.3055
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=122.0, call=True) = 39.2669
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=123.0, call=True) = 37.2258
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=124.0, call=True) = 36.9259
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=125.0, call=True) = 36.694
# ** resulting error:  235.08696423999996
# x= 1.100431857845055 0.10972477358311918 0.4445008263420544 0.05428960750814046 0.1201803063209607
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=100.0, call=True) = 61.2096
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=105.0, call=True) = 55.3912
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=110.0, call=True) = 50.9104
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=115.0, call=True) = 44.8636
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=120.0, call=True) = 40.7613
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=121.0, call=True) = 40.1326
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=122.0, call=True) = 36.7715
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=123.0, call=True) = 37.3153
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=124.0, call=True) = 37.3145
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=125.0, call=True) = 35.2148
# ** resulting error:  186.86946879999994
# x= 1.1004318414473426 0.10972478848428037 0.4445008263420544 0.05428960750814046 0.1201803063209607
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=100.0, call=True) = 62.8565
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=105.0, call=True) = 56.6728
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=110.0, call=True) = 49.7513
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=115.0, call=True) = 44.7145
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=120.0, call=True) = 40.1425
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=121.0, call=True) = 38.8096
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=122.0, call=True) = 37.6381
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=123.0, call=True) = 39.1738
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=124.0, call=True) = 36.2708
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=125.0, call=True) = 34.2679
# ** resulting error:  192.43571953999995
# x= 1.1004318414473426 0.10972477358311918 0.4445008412432156 0.05428960750814046 0.1201803063209607
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=100.0, call=True) = 59.8307
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=105.0, call=True) = 56.5602
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=110.0, call=True) = 50.2861
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=115.0, call=True) = 48.3306
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=120.0, call=True) = 42.2169
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=121.0, call=True) = 39.487
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=122.0, call=True) = 38.1421
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=123.0, call=True) = 37.2285
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=124.0, call=True) = 37.021
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=125.0, call=True) = 36.1264
# ** resulting error:  249.9460453299999
# x= 1.1004318414473426 0.10972477358311918 0.4445008263420544 0.05428962240930165 0.1201803063209607
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=100.0, call=True) = 61.5408
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=105.0, call=True) = 58.7938
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=110.0, call=True) = 51.202
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=115.0, call=True) = 44.7526
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=120.0, call=True) = 38.8483
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=121.0, call=True) = 39.0477
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=122.0, call=True) = 38.048
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=123.0, call=True) = 36.4302
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=124.0, call=True) = 35.4456
# The price of Option(s0=157.92, v0=0.1201803063209607, T=0.005479452054794521, K=125.0, call=True) = 36.7779
# ** resulting error:  197.1167698299999
# x= 1.1004318414473426 0.10972477358311918 0.4445008263420544 0.05428960750814046 0.1201803212221219
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=100.0, call=True) = 63.5106
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=105.0, call=True) = 59.5596
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=110.0, call=True) = 51.2005
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=115.0, call=True) = 44.2178
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=120.0, call=True) = 40.1684
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=121.0, call=True) = 39.6131
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=122.0, call=True) = 38.1385
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=123.0, call=True) = 38.3834
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=124.0, call=True) = 36.0804
# The price of Option(s0=157.92, v0=0.1201803212221219, T=0.005479452054794521, K=125.0, call=True) = 35.5805
# ** resulting error:  248.63163999999995
# x= 1.1112326434167612 0.12023824685118945 0.44083808325151563 0.06364920830574547 0.11684156233988671
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=100.0, call=True) = 60.7534
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=105.0, call=True) = 57.1436
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=110.0, call=True) = 50.7922
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=115.0, call=True) = 45.3822
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=120.0, call=True) = 42.6232
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=121.0, call=True) = 40.3016
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=122.0, call=True) = 40.6863
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=123.0, call=True) = 36.2568
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=124.0, call=True) = 37.154
# The price of Option(s0=157.92, v0=0.11684156233988671, T=0.005479452054794521, K=125.0, call=True) = 37.5292
# ** resulting error:  280.65455557
# x= 1.1031320419396973 0.11235314190013675 0.4435851405694197 0.05662950770754171 0.11934562032569221
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=100.0, call=True) = 59.5721
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=105.0, call=True) = 57.6838
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=110.0, call=True) = 50.6649
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=115.0, call=True) = 44.283
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=120.0, call=True) = 42.3808
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=121.0, call=True) = 40.4329
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=122.0, call=True) = 37.0887
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=123.0, call=True) = 37.3845
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=124.0, call=True) = 36.2744
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=125.0, call=True) = 34.7505
# ** resulting error:  201.13289845999998
# x= 1.1031320583776456 0.11235314190013675 0.4435851405694197 0.05662950770754171 0.11934562032569221
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=100.0, call=True) = 59.2411
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=105.0, call=True) = 54.1529
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=110.0, call=True) = 50.8702
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=115.0, call=True) = 46.8478
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=120.0, call=True) = 39.8453
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=121.0, call=True) = 39.6612
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=122.0, call=True) = 38.5265
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=123.0, call=True) = 37.0103
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=124.0, call=True) = 35.2135
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=125.0, call=True) = 35.986
# ** resulting error:  178.28042662
# x= 1.1031320419396973 0.11235315680129794 0.4435851405694197 0.05662950770754171 0.11934562032569221
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=100.0, call=True) = 61.7262
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=105.0, call=True) = 55.9747
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=110.0, call=True) = 49.7897
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=115.0, call=True) = 43.8615
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=120.0, call=True) = 40.5496
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=121.0, call=True) = 39.5665
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=122.0, call=True) = 38.287
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=123.0, call=True) = 39.3191
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=124.0, call=True) = 36.961
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=125.0, call=True) = 35.7291
# ** resulting error:  208.06482489999988
# x= 1.1031320419396973 0.11235314190013675 0.4435851554705809 0.05662950770754171 0.11934562032569221
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=100.0, call=True) = 60.2513
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=105.0, call=True) = 55.9348
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=110.0, call=True) = 51.3358
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=115.0, call=True) = 46.691
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=120.0, call=True) = 43.0036
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=121.0, call=True) = 43.2054
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=122.0, call=True) = 37.3957
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=123.0, call=True) = 39.3545
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=124.0, call=True) = 38.0608
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=125.0, call=True) = 36.5732
# ** resulting error:  326.87888710999994
# x= 1.1031320419396973 0.11235314190013675 0.4435851405694197 0.0566295226087029 0.11934562032569221
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=100.0, call=True) = 60.7135
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=105.0, call=True) = 55.794
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=110.0, call=True) = 50.4075
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=115.0, call=True) = 47.7639
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=120.0, call=True) = 41.716
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=121.0, call=True) = 40.0922
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=122.0, call=True) = 38.8929
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=123.0, call=True) = 37.7507
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=124.0, call=True) = 37.6773
# The price of Option(s0=157.92, v0=0.11934562032569221, T=0.005479452054794521, K=125.0, call=True) = 37.6044
# ** resulting error:  278.94296009999994
# x= 1.1031320419396973 0.11235314190013675 0.4435851405694197 0.05662950770754171 0.1193456352268534
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=100.0, call=True) = 59.4759
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=105.0, call=True) = 56.8464
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=110.0, call=True) = 51.9883
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=115.0, call=True) = 45.6555
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=120.0, call=True) = 41.3899
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=121.0, call=True) = 39.0737
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=122.0, call=True) = 37.7419
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=123.0, call=True) = 38.0434
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=124.0, call=True) = 36.6233
# The price of Option(s0=157.92, v0=0.1193456352268534, T=0.005479452054794521, K=125.0, call=True) = 34.9802
# ** resulting error:  205.44938671000003
# x= 1.103291539828514 0.1122997711631058 0.4426169889089795 0.056030427441169144 0.11931238653977685
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=100.0, call=True) = 62.1174
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=105.0, call=True) = 53.815
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=110.0, call=True) = 50.4053
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=115.0, call=True) = 46.7021
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=120.0, call=True) = 40.404
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=121.0, call=True) = 41.4672
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=122.0, call=True) = 38.2114
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=123.0, call=True) = 39.6973
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=124.0, call=True) = 36.7516
# The price of Option(s0=157.92, v0=0.11931238653977685, T=0.005479452054794521, K=125.0, call=True) = 36.2646
# ** resulting error:  259.07757307
# x= 1.1031719164119014 0.11233979921587901 0.44334310265430965 0.05647973764094857 0.11933731187921337
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=100.0, call=True) = 58.8712
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=105.0, call=True) = 57.3419
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=110.0, call=True) = 50.0663
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=115.0, call=True) = 46.4412
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=120.0, call=True) = 39.8237
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=121.0, call=True) = 41.0866
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=122.0, call=True) = 38.5454
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=123.0, call=True) = 38.5909
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=124.0, call=True) = 37.1402
# The price of Option(s0=157.92, v0=0.11933731187921337, T=0.005479452054794521, K=125.0, call=True) = 33.9952
# ** resulting error:  220.38713247999996
# x= 1.1031420105577483 0.11234980622907231 0.4435246310906422 0.05659206519089342 0.1193435432140725
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=100.0, call=True) = 62.3206
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=105.0, call=True) = 57.0386
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=110.0, call=True) = 50.8751
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=115.0, call=True) = 46.6317
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=120.0, call=True) = 40.4227
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=121.0, call=True) = 37.8531
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=122.0, call=True) = 38.4729
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=123.0, call=True) = 38.655
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=124.0, call=True) = 39.0948
# The price of Option(s0=157.92, v0=0.1193435432140725, T=0.005479452054794521, K=125.0, call=True) = 36.5186
# ** resulting error:  266.75355453000003
# x= 1.10313453409421 0.11235230798237064 0.44357001319972533 0.05662014707837964 0.11934510104778728
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=100.0, call=True) = 59.8853
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=105.0, call=True) = 56.118
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=110.0, call=True) = 50.2874
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=115.0, call=True) = 45.3473
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=120.0, call=True) = 39.8758
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=121.0, call=True) = 40.7684
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=122.0, call=True) = 39.9307
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=123.0, call=True) = 38.9431
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=124.0, call=True) = 37.2944
# The price of Option(s0=157.92, v0=0.11934510104778728, T=0.005479452054794521, K=125.0, call=True) = 33.7166
# ** resulting error:  219.40156736000003
# x= 1.1031326649783255 0.11235293342069522 0.4435813587269961 0.05662716755025119 0.11934549050621597
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=100.0, call=True) = 61.1656
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=105.0, call=True) = 55.3581
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=110.0, call=True) = 50.789
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=115.0, call=True) = 44.9004
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=120.0, call=True) = 41.6438
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=121.0, call=True) = 38.6056
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=122.0, call=True) = 39.4154
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=123.0, call=True) = 38.4857
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=124.0, call=True) = 36.4569
# The price of Option(s0=157.92, v0=0.11934549050621597, T=0.005479452054794521, K=125.0, call=True) = 37.2651
# ** resulting error:  230.89910919999988
# x= 1.1031321976993542 0.11235308978027636 0.4435841951088138 0.056628922668219075 0.11934558787082315
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=100.0, call=True) = 61.1341
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=105.0, call=True) = 56.2168
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=110.0, call=True) = 49.8047
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=115.0, call=True) = 44.6768
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=120.0, call=True) = 40.46
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=121.0, call=True) = 39.0873
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=122.0, call=True) = 42.9205
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=123.0, call=True) = 38.035
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=124.0, call=True) = 36.313
# The price of Option(s0=157.92, v0=0.11934558787082315, T=0.005479452054794521, K=125.0, call=True) = 34.3751
# ** resulting error:  237.0372669299999
# x= 1.1031320808796115 0.11235312887017165 0.44358490420426827 0.05662936144771105 0.11934561221197494
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=100.0, call=True) = 61.2901
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=105.0, call=True) = 56.1394
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=110.0, call=True) = 51.7205
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=115.0, call=True) = 45.7164
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=120.0, call=True) = 44.1066
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=121.0, call=True) = 40.0396
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=122.0, call=True) = 38.2373
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=123.0, call=True) = 36.6598
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=124.0, call=True) = 36.567
# The price of Option(s0=157.92, v0=0.11934561221197494, T=0.005479452054794521, K=125.0, call=True) = 35.0574
# ** resulting error:  247.01206638999997
# x= 1.1031320516746759 0.11235313864264547 0.44358508147813186 0.05662947114258404 0.1193456182972629
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=100.0, call=True) = 61.5543
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=105.0, call=True) = 54.9455
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=110.0, call=True) = 48.9642
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=115.0, call=True) = 46.603
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=120.0, call=True) = 39.6839
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=121.0, call=True) = 39.0597
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=122.0, call=True) = 39.222
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=123.0, call=True) = 37.9091
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=124.0, call=True) = 37.8004
# The price of Option(s0=157.92, v0=0.1193456182972629, T=0.005479452054794521, K=125.0, call=True) = 37.042
# ** resulting error:  227.16405765000007
# x= 1.1031320443734418 0.11235314108576393 0.44358512579659776 0.05662949856630229 0.11934561981858488
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=100.0, call=True) = 61.6608
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=105.0, call=True) = 55.3469
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=110.0, call=True) = 51.4799
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=115.0, call=True) = 46.7765
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=120.0, call=True) = 43.3504
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=121.0, call=True) = 38.7435
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=122.0, call=True) = 41.312
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=123.0, call=True) = 39.7163
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=124.0, call=True) = 36.3455
# The price of Option(s0=157.92, v0=0.11934561981858488, T=0.005479452054794521, K=125.0, call=True) = 35.9167
# ** resulting error:  307.43330974999986
# x= 1.1031320425481335 0.11235314169654355 0.4435851368762142 0.05662950542223186 0.11934562019891537
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=100.0, call=True) = 62.2471
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=105.0, call=True) = 56.2684
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=110.0, call=True) = 54.0447
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=115.0, call=True) = 46.6793
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=120.0, call=True) = 40.6756
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=121.0, call=True) = 38.7371
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=122.0, call=True) = 38.3956
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=123.0, call=True) = 38.027
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=124.0, call=True) = 36.5122
# The price of Option(s0=157.92, v0=0.11934562019891537, T=0.005479452054794521, K=125.0, call=True) = 35.9593
# ** resulting error:  255.81152900999996
# CPU times: total: 10.6 s
# Wall time: 11.1 s
